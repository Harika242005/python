# %%
#Projecct Problem Statement:Cows and Bulls(Select 3-digit randomly and limited hance of guess)
from random import randint
# Renaming the function to avoid shadowing the built-in random module
def generate_random_number():
  while True:
    # Corrected the typo from randnt to randint
    n = str(randint(100,999))
    if not(n[0] == n[1] or n[1] == n[2] or n[0] == n[2]):
      return n

name = input("Welcome to the Cows and Bulls game \nPlease Enter your name:")
print("Hi",name,"Lets Start")
chances = 10
cows = 0
bulls = 0
# Calling the corrected function name
num = str(generate_random_number())

while chances > 0:
  print("You have", chances,"Chances Left.")
  n = str(input("Enter Your Guess:"))
  if num == n:
    print("Great! You got it Right")
    break
  else:
    # Corrected indentation for the inner loop and print statements
    for i in range(0,3):
      if n[i] == num[i]:
        bulls = bulls + 1
      elif n[i] in num:
        cows = cows + 1
    # Corrected syntax in the print statement
    print("Keep going. You have", bulls, "Bulls and", cows, "cows.")
    bulls = 0
    cows = 0
    chances = chances - 1

print("The Correct answer is", num)
# Out:
# Welcome to the Cows and Bulls game
# Please Enter your name:harika
# Hi harika Lets Start
# You have 10 Chances Left.
# Enter Your Guess:314
# Keep going. You have 0 Bulls and 0 cows.
# You have 9 Chances Left.
# Enter Your Guess:456
# Keep going. You have 1 Bulls and 1 cows.
# You have 8 Chances Left.
# Enter Your Guess:426
# Keep going. You have 1 Bulls and 0 cows.
# You have 7 Chances Left.
# Enter Your Guess:425
# Keep going. You have 0 Bulls and 1 cows.
# You have 6 Chances Left.
# Enter Your Guess:256
# Keep going. You have 1 Bulls and 1 cows.
# You have 5 Chances Left.
# Enter Your Guess:576
# Great! You got it Right
# The Correct answer is 576
